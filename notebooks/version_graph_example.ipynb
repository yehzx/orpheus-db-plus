# %%
from orpheusplus.cli import _connect_table
import networkx as nx

# %%
table = _connect_table()
table.load_table("new_table")

# %%
pos = nx.nx_pydot.graphviz_layout(table.version_graph.G, prog="dot")
nx.draw(table.version_graph.G, pos=pos, with_labels=True)
